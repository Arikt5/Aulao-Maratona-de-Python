# %%
pyautogui.pause = 5
#abrir navegador
pyautogui.press("windleft")
pyautogui.write("chrome")
pyautogui.hotkey ('ctrl', 't')

#abrir drivechrome
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
time.sleep(2)
pyautogui.press("enter")

time.sleep(15)

#clicar na pasta exportar
pyautogui.click(497, 499, clicks=2)

time.sleep(10)

#baixar a planilha
pyautogui.click(543, 589)
time.sleep(2)
pyautogui.click(1737, 240)
time.sleep(2)
pyautogui.click(1521, 734)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_768/2977824186.py in <module>
# ----> 1 pyautogui.pause = 5
#       2 #abrir navegador
#       3 pyautogui.press("windleft")
#       4 pyautogui.write("chrome")
#       5 pyautogui.hotkey ('ctrl', 't')
#
# NameError: name 'pyautogui' is not defined

# %%
import pandas as pd
#ler a planilha
df = pd.read_excel(r'C:/Users/maryv/Downloads/Vendas - Dez.xlsx')
display(df)
faturamento = df['Valor Final'].sum()
quantidade = df['Quantidade'].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
pyautogui.pause = 5
#abrir navegador
pyautogui.press("windleft")
pyautogui.write("chrome")
pyautogui.hotkey('ctrl', 't')

#abrir google chrome
link = "mail.google.com"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
time.sleep(2)
pyautogui.press("enter")

time.sleep(10)

#escrevendo o e-mail
pyautogui.click(176, 245)
time.sleep(2)
pyautogui.write('mary.vitoriahp+diretoria@gmail.com')
pyautogui.press('tab')
pyautogui.press('tab')
pyperclip.copy('Relatório de Vendas')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

texto = f"""
Prezados,bom dia

O faturamento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de:{quantidade:,}

Abs
Maria Vitória Silva"""

pyperclip.copy(texto)
pyautogui.hotkey('ctrl', 'v')
pyautogui.hotkey('ctrl', 'enter')

# %%
time.sleep(10) 
pyautogui.position()
